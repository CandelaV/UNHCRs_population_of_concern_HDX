# %%
from hdx.hdx_configuration import Configuration
from hdx.data.dataset import Dataset

# %%
Configuration.create(hdx_site='prod', user_agent='A_Quick_Example', hdx_read_only=True)
# Out:
# 'https://data.humdata.org/'

# %%
dataset = Dataset.read_from_hdx('refugees-residing-tza')
dataset
# Out:
# {'data_update_frequency': '0', 'license_title': 'cc-by-igo', 'maintainer': '7ae95211-71dd-484e-8538-2c625315eb56', 'relationships_as_object': [], 'private': False, 'dataset_date': '01/01/1951-12/31/2025', 'num_tags': 14, 'solr_additions': '{"countries": ["United Republic of Tanzania"]}', 'id': 'b3643f04-a170-48c8-a368-3ef4c5153117', 'metadata_created': '2015-12-03T20:24:19.145583', 'archived': False, 'caveats': 'Live data from UNHCR (continuously updating).\n\nIn some recent data, figures between 1 and 4 have been replaced with an asterisk (*). These represent situations where the figures are being kept confidential to protect the anonymity of individuals. Such figures are not included in any totals.\n\nSome country data may be missing, where UNHCR adds extra text after the country name (e.g. "France: all regions").', 'metadata_modified': '2019-02-07T18:11:48.540703', 'author': 'Laurent Pitoiset', 'author_email': 'pitoiset@unhcr.org', 'subnational': '0', 'state': 'active', 'has_geodata': False, 'methodology': 'Census', 'version': None, 'is_requestdata_type': False, 'license_id': 'cc-by-igo', 'type': 'dataset', 'is_fresh': False, 'has_showcases': False, 'dataset_preview': 'first_resource', 'num_resources': 1, 'dataset_source': 'UNHCR', 'tags': [{'vocabulary_id': None, 'state': 'active', 'display_name': 'asylum-seekers', 'id': 'b927ab93-fac2-4628-a4f3-1fc12ce2cf14', 'name': 'asylum-seekers'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'hxl', 'id': '5f985f56-ee63-40a7-9052-fd53269737ff', 'name': 'hxl'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'idp', 'id': '9afc7d18-f686-4fd6-8013-aa48734eb83d', 'name': 'idp'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'idps', 'id': 'c8589b66-2b68-4fa4-992d-187e10696a8c', 'name': 'idps'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'internally displaced', 'id': '85d7b638-36a0-4c35-97d4-9c9cbb23b3c5', 'name': 'internally displaced'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'migration', 'id': '62c9689b-bc7e-48fe-805a-6cb349ad58b4', 'name': 'migration'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'protection', 'id': 'b131f272-0234-4194-8913-88f3c6f0b6b8', 'name': 'protection'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'refugee', 'id': '5bb09d1f-4a0c-4425-90b9-dc9fe501f835', 'name': 'refugee'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'refugees', 'id': 'd6ffa64a-3ea5-49f0-b9c7-07bf2dc09d76', 'name': 'refugees'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'returned', 'id': '8bf2358a-328a-482f-99ed-5bb7bcf4bfbf', 'name': 'returned'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'returned refugees', 'id': '27e88d18-66f9-453f-9f0c-c6fb25ac527b', 'name': 'returned refugees'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'returnees', 'id': '099eaadc-5145-4a9f-8200-0917cc286e1f', 'name': 'returnees'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'stateless', 'id': '185f1e6b-2b43-4ce8-987c-7533ea4e751b', 'name': 'stateless'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'stateless persons', 'id': '1f95ca01-7852-4987-90dd-1175f213110b', 'name': 'stateless persons'}], 'last_modified': '2019-02-07T18:11:48.539244', 'revision_id': 'd3829765-c49e-4d05-8d1b-0a841e31204b', 'groups': [{'display_name': 'United Republic of Tanzania', 'description': '', 'image_display_url': '', 'title': 'United Republic of Tanzania', 'id': 'tza', 'name': 'tza'}], 'creator_user_id': '7ae95211-71dd-484e-8538-2c625315eb56', 'has_quickcharts': True, 'relationships_as_subject': [], 'total_res_downloads': 14, 'organization': {'description': 'The Office of the United Nations High Commissioner for Refugees was established on December 14, 1950 by the United Nations General Assembly. The agency is mandated to lead and co-ordinate international action to protect refugees and resolve refugee problems worldwide. Its primary purpose is to safeg ...

# %%
dataset.get_dataset_date()
# Out:
# '1951-01-01'

# %%
resources = dataset.get_resources()
resources
# Out:
# [{'cache_last_updated': None, 'package_id': 'b3643f04-a170-48c8-a368-3ef4c5153117', 'datastore_active': False, 'id': 'd7ec1bec-7f6b-407b-9ee0-27f916e7c4c6', 'size': None, 'revision_last_updated': '2019-02-07T18:11:48.539244', 'state': 'active', 'hash': '', 'description': 'UNHCR persons of concern residing in Tanzania.', 'format': 'CSV', 'hdx_rel_url': 'http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/persons_of_concern.hxl&filter01=select&select-query01-01=%23country%2Bresidence=United%20Rep.%20of%20Tanzania', 'last_modified': '2019-02-07T18:11:48.539244', 'url_type': None, 'mimetype': 'text/csv', 'cache_url': None, 'name': 'unhcr_persons_of_concern_residence_tza.csv', 'created': '2017-10-24T21:31:49.204691', 'url': 'http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/persons_of_concern.hxl&filter01=select&select-query01-01=%23country%2Bresidence=United%20Rep.%20of%20Tanzania', 'mimetype_inner': None, 'position': 0, 'revision_id': '55f08aea-fd79-4c4e-9bd7-f13f9999d6a7', 'resource_type': None}]

# %%
resources[0].get_file_type()
# Out:
# 'CSV'

# %%
type(resources[0])
# Out:
# hdx.data.resource.Resource

# %%
resources[0].download("./data")
# Out:
# ('http://proxy.hxlstandard.org/data.csv?url=http%3A//popstats.unhcr.org/en/persons_of_concern.hxl&filter01=select&select-query01-01=%23country%2Bresidence=United%20Rep.%20of%20Tanzania',
#  './data/unhcr_persons_of_concern_residence_tza.csv1.CSV')

# %%
type(resources[0].get_dataset())
# Out:
# hdx.data.dataset.Dataset

# %%
list_datasets = Dataset.get_all_dataset_names()

# %%
len(list_datasets)
# Out:
# 12720

# %%
residing = [k for k in list_datasets if 'refugees-residing' in k]
residing
# Out:
# ['refugees-residing-abw',
#  'refugees-residing-afg',
#  'refugees-residing-ago',
#  'refugees-residing-alb',
#  'refugees-residing-ant',
#  'refugees-residing-are',
#  'refugees-residing-arg',
#  'refugees-residing-arm',
#  'refugees-residing-atg',
#  'refugees-residing-aus',
#  'refugees-residing-aut',
#  'refugees-residing-aze',
#  'refugees-residing-bdi',
#  'refugees-residing-bel',
#  'refugees-residing-ben',
#  'refugees-residing-bes',
#  'refugees-residing-bfa',
#  'refugees-residing-bgd',
#  'refugees-residing-bgr',
#  'refugees-residing-bhr',
#  'refugees-residing-bhs',
#  'refugees-residing-bih',
#  'refugees-residing-blr',
#  'refugees-residing-blz',
#  'refugees-residing-bol',
#  'refugees-residing-bra',
#  'refugees-residing-brb',
#  'refugees-residing-brn',
#  'refugees-residing-btn',
#  'refugees-residing-bwa',
#  'refugees-residing-caf',
#  'refugees-residing-can',
#  'refugees-residing-che',
#  'refugees-residing-chl',
#  'refugees-residing-chn',
#  'refugees-residing-civ',
#  'refugees-residing-cmr',
#  'refugees-residing-cod',
#  'refugees-residing-cog',
#  'refugees-residing-col',
#  'refugees-residing-com',
#  'refugees-residing-cpv',
#  'refugees-residing-cri',
#  'refugees-residing-cub',
#  'refugees-residing-cuw',
#  'refugees-residing-cym',
#  'refugees-residing-cyp',
#  'refugees-residing-cze',
#  'refugees-residing-deu',
#  'refugees-residing-dji',
#  'refugees-residing-dnk',
#  'refugees-residing-dom',
#  'refugees-residing-dza',
#  'refugees-residing-ecu',
#  'refugees-residing-egy',
#  'refugees-residing-eri',
#  'refugees-residing-esp',
#  'refugees-residing-est',
#  'refugees-residing-eth',
#  'refugees-residing-fin',
#  'refugees-residing-fji',
#  'refugees-residing-fra',
#  'refugees-residing-fsm',
#  'refugees-residing-gab',
#  'refugees-residing-gbr',
#  'refugees-residing-geo',
#  'refugees-residing-gha',
#  'refugees-residing-gin',
#  'refugees-residing-gmb',
#  'refugees-residing-gnb',
#  'refugees-residing-gnq',
#  'refugees-residing-grc',
#  'refugees-residing-grd',
#  'refugees-residing-gtm',
#  'refugees-residing-guf',
#  'refugees-residing-guy',
#  'refugees-residing-hkg',
#  'refugees-residing-hnd',
#  'refugees-residing-hrv',
#  'refugees-residing-hti',
#  'refugees-residing-hun',
#  'refugees-residing-idn',
#  'refugees-residing-ind',
#  'refugees-residing-irl',
#  'refugees-residing-irn',
#  'refugees-residing-irq',
#  'refugees-residing-isl',
#  'refugees-residing-isr',
#  'refugees-residing-ita',
#  'refugees-residing-jam',
#  'refugees-residing-jor',
#  'refugees-residing-jpn',
#  'refugees-residing-kaz',
#  'refugees-residing-ken',
#  'refugees-residing-kgz',
#  'refugees-residing-khm',
#  'refugees-residing-kna',
#  'refugees-residing-kor',
#  'refugees-residing-kwt',
#  'refugees-residing-lao',
#  'refugees-residing-lbn',
#  'refugees-residing-lbr',
#  'refugees-residing-lby',
#  'refugees-residing-lca',
#  'refugees-residing-lie',
#  'refugees-residing-lka',
#  'refugees-residing-lso',
#  'refugees-residing-ltu',
#  'refugees-residing-lux',
#  'refugees-residing-lva',
#  'refugees-residing-mac',
#  'refugees-residing-mar',
#  'refugees-residing-mco',
#  'refugees-residing-mda',
#  'refugees-residing-mdg',
#  'refugees-residing-mex',
#  'refugees-residing-mkd',
#  'refugees-residing-mli',
#  'refugees-residing-mlt',
#  'refugees-residing-mmr',
#  'refugees-residing-mne',
#  'refugees-residing-mng',
#  'refugees-residing-moz',
#  'refugees-residing-mrt',
#  'refugees-residing-msr',
#  'refugees-residing-mus',
#  'refugees-residing-mwi',
#  'refugees-residing-mys',
#  'refugees-residing-nam',
#  'refugees-residing-ner',
#  'refugees-residing-nga',
#  'refugees-residing-nic',
#  'refugees-residing-nld',
#  'refugees-residing-nor',
#  'refugees-residing-npl',
#  'refugees-residing-nru',
#  'refugees-residing-nzl',
#  'refugees-residing-omn',
#  'refugees-residing-pak',
#  'refugees-residing-pan',
#  'refugees-residing-per',
#  'refugees-residing-phl',
#  'refugees-residing-plw',
#  'refugees-residing-png',
#  'refugees-residing-pol',
#  'refugees-residing-prt',
#  'refugees-residing-pry',
#  'refugees-residing-pse',
#  'refugees-residing-qat',
#  'refugees-residing-rou',
#  'refugees-residing-rus',
#  'refugees-residing-rwa',
#  'refugees-residing-sau',
#  'refugees-residing-sdn',
#  'refugees-residing-sen',
#  'refugees-residing-sgp',
#  'refugees-residing-slb',
#  'refugees-residing-sle',
#  'refugees-residing-slv',
#  'refugees-residing-som',
#  'refugees-residing-srb',
#  'refugees-residing-ssd',
#  'refugees-residing-sur',
#  'refugees-residing-svk',
#  'refugees-residing-svn',
#  'refugees-residing-swe',
#  'refugees-residing-swz',
#  'refugees-residing-syr',
#  'refugees-residing-tca',
#  'refugees-residing-tcd',
#  'refugees-residing-tgo',
#  'refugees-residing-tha',
#  'refugees-residing-tjk',
#  'refugees-residing-tkm',
#  'refugees-residing-tls',
#  'refugees-residing-ton',
#  'refugees-residing-tto',
#  'refugees-residing-tun',
#  'refugees-residing-tur',
#  'refugees-residing-tza',
#  'refugees-residing-uga',
#  'refugees-residing-ukr',
#  'refugees-residing-ury',
#  'refugees-residing-usa',
#  'refugees-residing-uzb',
#  'refugees-residing-vct',
#  'refugees-residing-ven',
#  'refugees-residing-vgb',
#  'refugees-residing-vnm',
#  'refugees-residing-vut',
#  'refugees-residing-yem',
#  'refugees-residing-zaf',
#  'refugees-residing-zmb',
#  'refugees-residing-zwe']

# %%
originating = [k for k in list_datasets if 'refugees-originating' in k ]
originating
# Out:
# ['refugees-originating-abw',
#  'refugees-originating-afg',
#  'refugees-originating-ago',
#  'refugees-originating-alb',
#  'refugees-originating-ant',
#  'refugees-originating-are',
#  'refugees-originating-arg',
#  'refugees-originating-arm',
#  'refugees-originating-atg',
#  'refugees-originating-aus',
#  'refugees-originating-aut',
#  'refugees-originating-aze',
#  'refugees-originating-bdi',
#  'refugees-originating-bel',
#  'refugees-originating-ben',
#  'refugees-originating-bes',
#  'refugees-originating-bfa',
#  'refugees-originating-bgd',
#  'refugees-originating-bgr',
#  'refugees-originating-bhr',
#  'refugees-originating-bhs',
#  'refugees-originating-bih',
#  'refugees-originating-blr',
#  'refugees-originating-blz',
#  'refugees-originating-bol',
#  'refugees-originating-bra',
#  'refugees-originating-brb',
#  'refugees-originating-brn',
#  'refugees-originating-btn',
#  'refugees-originating-bwa',
#  'refugees-originating-caf',
#  'refugees-originating-can',
#  'refugees-originating-che',
#  'refugees-originating-chl',
#  'refugees-originating-chn',
#  'refugees-originating-civ',
#  'refugees-originating-cmr',
#  'refugees-originating-cod',
#  'refugees-originating-cog',
#  'refugees-originating-col',
#  'refugees-originating-com',
#  'refugees-originating-cpv',
#  'refugees-originating-cri',
#  'refugees-originating-cub',
#  'refugees-originating-cuw',
#  'refugees-originating-cym',
#  'refugees-originating-cyp',
#  'refugees-originating-cze',
#  'refugees-originating-deu',
#  'refugees-originating-dji',
#  'refugees-originating-dnk',
#  'refugees-originating-dom',
#  'refugees-originating-dza',
#  'refugees-originating-ecu',
#  'refugees-originating-egy',
#  'refugees-originating-eri',
#  'refugees-originating-esp',
#  'refugees-originating-est',
#  'refugees-originating-eth',
#  'refugees-originating-fin',
#  'refugees-originating-fji',
#  'refugees-originating-fra',
#  'refugees-originating-fsm',
#  'refugees-originating-gab',
#  'refugees-originating-gbr',
#  'refugees-originating-geo',
#  'refugees-originating-gha',
#  'refugees-originating-gin',
#  'refugees-originating-gmb',
#  'refugees-originating-gnb',
#  'refugees-originating-gnq',
#  'refugees-originating-grc',
#  'refugees-originating-grd',
#  'refugees-originating-gtm',
#  'refugees-originating-guf',
#  'refugees-originating-guy',
#  'refugees-originating-hkg',
#  'refugees-originating-hnd',
#  'refugees-originating-hrv',
#  'refugees-originating-hti',
#  'refugees-originating-hun',
#  'refugees-originating-idn',
#  'refugees-originating-ind',
#  'refugees-originating-irl',
#  'refugees-originating-irn',
#  'refugees-originating-irq',
#  'refugees-originating-isl',
#  'refugees-originating-isr',
#  'refugees-originating-ita',
#  'refugees-originating-jam',
#  'refugees-originating-jor',
#  'refugees-originating-jpn',
#  'refugees-originating-kaz',
#  'refugees-originating-ken',
#  'refugees-originating-kgz',
#  'refugees-originating-khm',
#  'refugees-originating-kna',
#  'refugees-originating-kor',
#  'refugees-originating-kwt',
#  'refugees-originating-lao',
#  'refugees-originating-lbn',
#  'refugees-originating-lbr',
#  'refugees-originating-lby',
#  'refugees-originating-lca',
#  'refugees-originating-lie',
#  'refugees-originating-lka',
#  'refugees-originating-lso',
#  'refugees-originating-ltu',
#  'refugees-originating-lux',
#  'refugees-originating-lva',
#  'refugees-originating-mac',
#  'refugees-originating-mar',
#  'refugees-originating-mco',
#  'refugees-originating-mda',
#  'refugees-originating-mdg',
#  'refugees-originating-mex',
#  'refugees-originating-mkd',
#  'refugees-originating-mli',
#  'refugees-originating-mlt',
#  'refugees-originating-mmr',
#  'refugees-originating-mne',
#  'refugees-originating-mng',
#  'refugees-originating-moz',
#  'refugees-originating-mrt',
#  'refugees-originating-msr',
#  'refugees-originating-mus',
#  'refugees-originating-mwi',
#  'refugees-originating-mys',
#  'refugees-originating-nam',
#  'refugees-originating-ner',
#  'refugees-originating-nga',
#  'refugees-originating-nic',
#  'refugees-originating-nld',
#  'refugees-originating-nor',
#  'refugees-originating-npl',
#  'refugees-originating-nru',
#  'refugees-originating-nzl',
#  'refugees-originating-omn',
#  'refugees-originating-pak',
#  'refugees-originating-pan',
#  'refugees-originating-per',
#  'refugees-originating-phl',
#  'refugees-originating-plw',
#  'refugees-originating-png',
#  'refugees-originating-pol',
#  'refugees-originating-prt',
#  'refugees-originating-pry',
#  'refugees-originating-pse',
#  'refugees-originating-qat',
#  'refugees-originating-rou',
#  'refugees-originating-rus',
#  'refugees-originating-rwa',
#  'refugees-originating-sau',
#  'refugees-originating-sdn',
#  'refugees-originating-sen',
#  'refugees-originating-sgp',
#  'refugees-originating-slb',
#  'refugees-originating-sle',
#  'refugees-originating-slv',
#  'refugees-originating-som',
#  'refugees-originating-srb',
#  'refugees-originating-ssd',
#  'refugees-originating-sur',
#  'refugees-originating-svk',
#  'refugees-originating-svn',
#  'refugees-originating-swe',
#  'refugees-originating-swz',
#  'refugees-originating-syr',
#  'refugees-originating-tca',
#  'refugees-originating-tcd',
#  'refugees-originating-tgo',
#  'refugees-originating-tha',
#  'refugees-originating-tjk',
#  'refugees-originating-tkm',
#  'refugees-originating-tls',
#  'refugees-originating-ton',
#  'refugees-originating-tto',
#  'refugees-originating-tun',
#  'refugees-originating-tur',
#  'refugees-originating-tza',
#  'refugees-originating-uga',
#  'refugees-originating-ukr',
#  'refugees-originating-ury',
#  'refugees-originating-usa',
#  'refugees-originating-uzb',
#  'refugees-originating-vct',
#  'refugees-originating-ven',
#  'refugees-originating-vgb',
#  'refugees-originating-vnm',
#  'refugees-originating-vut',
#  'refugees-originating-yem',
#  'refugees-originating-zaf',
#  'refugees-originating-zmb',
#  'refugees-originating-zwe']

# %%
indicators = [k for k in list_datasets if 'world-bank-indicators-for' in k]
indicators = [k for k in indicators if 'showcase' not in k]
indicators
# Out:
# ['world-bank-indicators-for-afghanistan',
#  'world-bank-indicators-for-albania',
#  'world-bank-indicators-for-algeria',
#  'world-bank-indicators-for-american-samoa',
#  'world-bank-indicators-for-andorra',
#  'world-bank-indicators-for-angola',
#  'world-bank-indicators-for-antigua-and-barbuda',
#  'world-bank-indicators-for-argentina',
#  'world-bank-indicators-for-armenia',
#  'world-bank-indicators-for-aruba',
#  'world-bank-indicators-for-australia',
#  'world-bank-indicators-for-austria',
#  'world-bank-indicators-for-azerbaijan',
#  'world-bank-indicators-for-bahamas-the',
#  'world-bank-indicators-for-bahrain',
#  'world-bank-indicators-for-bangladesh',
#  'world-bank-indicators-for-barbados',
#  'world-bank-indicators-for-belarus',
#  'world-bank-indicators-for-belgium',
#  'world-bank-indicators-for-belize',
#  'world-bank-indicators-for-benin',
#  'world-bank-indicators-for-bermuda',
#  'world-bank-indicators-for-bhutan',
#  'world-bank-indicators-for-bolivia',
#  'world-bank-indicators-for-bosnia-and-herzegovina',
#  'world-bank-indicators-for-botswana',
#  'world-bank-indicators-for-brazil',
#  'world-bank-indicators-for-british-virgin-islands',
#  'world-bank-indicators-for-brunei-darussalam',
#  'world-bank-indicators-for-bulgaria',
#  'world-bank-indicators-for-burkina-faso',
#  'world-bank-indicators-for-burundi',
#  'world-bank-indicators-for-cabo-verde',
#  'world-bank-indicators-for-cambodia',
#  'world-bank-indicators-for-cameroon',
#  'world-bank-indicators-for-canada',
#  'world-bank-indicators-for-cayman-islands',
#  'world-bank-indicators-for-central-african-republic',
#  'world-bank-indicators-for-chad',
#  'world-bank-indicators-for-channel-islands',
#  'world-bank-indicators-for-chile',
#  'world-bank-indicators-for-china',
#  'world-bank-indicators-for-colombia',
#  'world-bank-indicators-for-comoros',
#  'world-bank-indicators-for-congo-dem-rep',
#  'world-bank-indicators-for-congo-rep',
#  'world-bank-indicators-for-costa-rica',
#  'world-bank-indicators-for-cote-divoire',
#  'world-bank-indicators-for-croatia',
#  'world-bank-indicators-for-cuba',
#  'world-bank-indicators-for-curacao',
#  'world-bank-indicators-for-cyprus',
#  'world-bank-indicators-for-czech-republic',
#  'world-bank-indicators-for-denmark',
#  'world-bank-indicators-for-djibouti',
#  'world-bank-indicators-for-dominica',
#  'world-bank-indicators-for-dominican-republic',
#  'world-bank-indicators-for-ecuador',
#  'world-bank-indicators-for-egypt-arab-rep',
#  'world-bank-indicators-for-el-salvador',
#  'world-bank-indicators-for-equatorial-guinea',
#  'world-bank-indicators-for-eritrea',
#  'world-bank-indicators-for-estonia',
#  'world-bank-indicators-for-eswatini',
#  'world-bank-indicators-for-ethiopia',
#  'world-bank-indicators-for-faroe-islands',
#  'world-bank-indicators-for-fiji',
#  'world-bank-indicators-for-finland',
#  'world-bank-indicators-for-france',
#  'world-bank-indicators-for-french-polynesia',
#  'world-bank-indicators-for-gabon',
#  'world-bank-indicators-for-gambia-the',
#  'world-bank-indicators-for-georgia',
#  'world-bank-indicators-for-germany',
#  'world-bank-indicators-for-ghana',
#  'world-bank-indicators-for-gibraltar',
#  'world-bank-indicators-for-greece',
#  'world-bank-indicators-for-greenland',
#  'world-bank-indicators-for-grenada',
#  'world-bank-indicators-for-guam',
#  'world-bank-indicators-for-guatemala',
#  'world-bank-indicators-for-guinea',
#  'world-bank-indicators-for-guinea-bissau',
#  'world-bank-indicators-for-guyana',
#  'world-bank-indicators-for-haiti',
#  'world-bank-indicators-for-honduras',
#  'world-bank-indicators-for-hong-kong-sar-china',
#  'world-bank-indicators-for-hungary',
#  'world-bank-indicators-for-iceland',
#  'world-bank-indicators-for-india',
#  'world-bank-indicators-for-indonesia',
#  'world-bank-indicators-for-iran-islamic-rep',
#  'world-bank-indicators-for-iraq',
#  'world-bank-indicators-for-ireland',
#  'world-bank-indicators-for-israel',
#  'world-bank-indicators-for-italy',
#  'world-bank-indicators-for-jamaica',
#  'world-bank-indicators-for-japan',
#  'world-bank-indicators-for-jordan',
#  'world-bank-indicators-for-kazakhstan',
#  'world-bank-indicators-for-kenya',
#  'world-bank-indicators-for-kiribati',
#  'world-bank-indicators-for-korea-dem-peoples-rep',
#  'world-bank-indicators-for-korea-rep',
#  'world-bank-indicators-for-kuwait',
#  'world-bank-indicators-for-kyrgyz-republic',
#  'world-bank-indicators-for-lao-pdr',
#  'world-bank-indicators-for-latvia',
#  'world-bank-indicators-for-lebanon',
#  'world-bank-indicators-for-lesotho',
#  'world-bank-indicators-for-liberia',
#  'world-bank-indicators-for-libya',
#  'world-bank-indicators-for-liechtenstein',
#  'world-bank-indicators-for-lithuania',
#  'world-bank-indicators-for-luxembourg',
#  'world-bank-indicators-for-macao-sar-china',
#  'world-bank-indicators-for-macedonia-fyr',
#  'world-bank-indicators-for-madagascar',
#  'world-bank-indicators-for-malawi',
#  'world-bank-indicators-for-malaysia',
#  'world-bank-indicators-for-maldives',
#  'world-bank-indicators-for-mali',
#  'world-bank-indicators-for-malta',
#  'world-bank-indicators-for-marshall-islands',
#  'world-bank-indicators-for-mauritania',
#  'world-bank-indicators-for-mauritius',
#  'world-bank-indicators-for-mexico',
#  'world-bank-indicators-for-micronesia-fed-sts',
#  'world-bank-indicators-for-moldova',
#  'world-bank-indicators-for-monaco',
#  'world-bank-indicators-for-mongolia',
#  'world-bank-indicators-for-montenegro',
#  'world-bank-indicators-for-morocco',
#  'world-bank-indicators-for-mozambique',
#  'world-bank-indicators-for-myanmar',
#  'world-bank-indicators-for-namibia',
#  'world-bank-indicators-for-nauru',
#  'world-bank-indicators-for-nepal',
#  'world-bank-indicators-for-netherlands',
#  'world-bank-indicators-for-new-caledonia',
#  'world-bank-indicators-for-new-zealand',
#  'world-bank-indicators-for-nicaragua',
#  'world-bank-indicators-for-niger',
#  'world-bank-indicators-for-nigeria',
#  'world-bank-indicators-for-northern-mariana-islands',
#  'world-bank-indicators-for-norway',
#  'world-bank-indicators-for-oman',
#  'world-bank-indicators-for-pakistan',
#  'world-bank-indicators-for-palau',
#  'world-bank-indicators-for-panama',
#  'world-bank-indicators-for-papua-new-guinea',
#  'world-bank-indicators-for-paraguay',
#  'world-bank-indicators-for-peru',
#  'world-bank-indicators-for-philippines',
#  'world-bank-indicators-for-poland',
#  'world-bank-indicators-for-portugal',
#  'world-bank-indicators-for-puerto-rico',
#  'world-bank-indicators-for-qatar',
#  'world-bank-indicators-for-romania',
#  'world-bank-indicators-for-russian-federation',
#  'world-bank-indicators-for-rwanda',
#  'world-bank-indicators-for-samoa',
#  'world-bank-indicators-for-san-marino',
#  'world-bank-indicators-for-sao-tome-and-principe',
#  'world-bank-indicators-for-saudi-arabia',
#  'world-bank-indicators-for-senegal',
#  'world-bank-indicators-for-serbia',
#  'world-bank-indicators-for-seychelles',
#  'world-bank-indicators-for-sierra-leone',
#  'world-bank-indicators-for-singapore',
#  'world-bank-indicators-for-sint-maarten-dutch-part',
#  'world-bank-indicators-for-slovak-republic',
#  'world-bank-indicators-for-slovenia',
#  'world-bank-indicators-for-solomon-islands',
#  'world-bank-indicators-for-somalia',
#  'world-bank-indicators-for-south-africa',
#  'world-bank-indicators-for-south-sudan',
#  'world-bank-indicators-for-spain',
#  'world-bank-indicators-for-sri-lanka',
#  'world-bank-indicators-for-st-kitts-and-nevis',
#  'world-bank-indicators-for-st-lucia',
#  'world-bank-indicators-for-st-martin-french-part',
#  'world-bank-indicators-for-st-vincent-and-the-grenadines',
#  'world-bank-indicators-for-sudan',
#  'world-bank-indicators-for-suriname',
#  'world-bank-indicators-for-swaziland',
#  'world-bank-indicators-for-sweden',
#  'world-bank-indicators-for-switzerland',
#  'world-bank-indicators-for-syrian-arab-republic',
#  'world-bank-indicators-for-taiwan-china',
#  'world-bank-indicators-for-tajikistan',
#  'world-bank-indicators-for-tanzania',
#  'world-bank-indicators-for-thailand',
#  'world-bank-indicators-for-timor-leste',
#  'world-bank-indicators-for-togo',
#  'world-bank-indicators-for-tonga',
#  'world-bank-indicators-for-trinidad-and-tobago',
#  'world-bank-indicators-for-tunisia',
#  'world-bank-indicators-for-turkey',
#  'world-bank-indicators-for-turkmenistan',
#  'world-bank-indicators-for-turks-and-caicos-islands',
#  'world-bank-indicators-for-tuvalu',
#  'world-bank-indicators-for-uganda',
#  'world-bank-indicators-for-ukraine',
#  'world-bank-indicators-for-united-arab-emirates',
#  'world-bank-indicators-for-united-kingdom',
#  'world-bank-indicators-for-united-states',
#  'world-bank-indicators-for-uruguay',
#  'world-bank-indicators-for-uzbekistan',
#  'world-bank-indicators-for-vanuatu',
#  'world-bank-indicators-for-venezuela-rb',
#  'world-bank-indicators-for-vietnam',
#  'world-bank-indicators-for-virgin-islands-u-s',
#  'world-bank-indicators-for-west-bank-and-gaza',
#  'world-bank-indicators-for-yemen-rep',
#  'world-bank-indicators-for-zambia',
#  'world-bank-indicators-for-zimbabwe']
